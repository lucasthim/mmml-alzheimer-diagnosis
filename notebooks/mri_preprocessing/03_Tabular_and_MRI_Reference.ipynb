# %% [markdown]
# # Tabular Reference for Ensemble

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.pyplot as plt
import scipy.stats as sp
from joblib import dump, load
from collections import namedtuple

# %matplotlib inline
plt.style.use('seaborn')
pd.set_option('display.max_columns', 150)
pd.set_option('display.max_rows', 150)

from google.colab import drive
import os

drive.mount('/content/gdrive', force_remount=True)
os.chdir('/content/gdrive/MyDrive/Lucas_Thimoteo/mmml-alzheimer-diagnosis')
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# # Downloading Images

# %%
cognitive_data_path = '/content/gdrive/MyDrive/Lucas_Thimoteo/data/tabular/COGNITIVE_DATA_PREPROCESSED.csv'
classes = [1,0]
chunks = 1000 

df_cog = pd.read_csv(cognitive_data_path).dropna().query("IMAGEUID != 999999 and DIAGNOSIS in @classes")

subjects = df_cog['IMAGEUID'].shape[0]
max_count =  len(range(0,df_cog['IMAGEUID'].shape[0],chunks))
for count,i in enumerate(range(0,subjects,chunks)):
    print(f"Images to download: {count+1}/{max_count}")
    image_chunk = df_cog.iloc[i:i+chunks]['IMAGEUID'].tolist()
    print("Chunk size:",len(image_chunk))
    print(image_chunk)
    print("-------------------------------")
# Out:
# Images to download: 1/2
# Chunk size: 1000
# ...
