# %%
import os

# %load_ext autoreload
# %autoreload 2

# from google.colab import drive
# drive.mount('/content/gdrive', force_remount=True)
# os.chdir('/content/gdrive/MyDrive/Lucas_Thimoteo/mmml-alzheimer-diagnosis/src')

# %%
# !python3 -m pip install -e /content/gdrive/MyDrive/Lucas_Thimoteo/mmml-alzheimer-diagnosis/.

# %%
# !pip install antspyx

# %% [markdown]
# # Concatenating MRI_REFERENCEs

# %%
from src.data_extraction.mri_reference_concat import *

# %%
input = ['/content/gdrive/MyDrive/Lucas_Thimoteo/data/reference/MPRAGE_REFERENCE.csv',
         '/content/gdrive/MyDrive/Lucas_Thimoteo/data/reference/REFERENCE_MRI_ENSEMBLE_01.csv',
         '/content/gdrive/MyDrive/Lucas_Thimoteo/data/reference/REFERENCE_MRI_ENSEMBLE_02.csv']

output = '/content/gdrive/MyDrive/Lucas_Thimoteo/data/reference/RAW_MRI_REFERENCE.csv'

# %%
df_reference = concatenate_reference_files(input,output)
# Out:
# Found 3 files to concatenate...
# Reading  /content/gdrive/MyDrive/Lucas_Thimoteo/data/reference/MPRAGE_REFERENCE.csv
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-21-80488d6da823> in <module>()
# ----> 1 df_reference = concatenate_reference_files(input,output)
#
# /content/gdrive/MyDrive/Lucas_Thimoteo/mmml-alzheimer-diagnosis/src/data_extraction/mri_reference_concat.py in concatenate_reference_files(input, output)
#      29     for file in files:
#      30         print("Reading ",file)
# ---> 31         concat_df.append(load_reference_table(file))
#      32
#      33     df_reference = pd.concat(concat_df)
#
# NameError: name 'load_reference_table' is not defined

# %%
from src.data_extraction.mri_reference_concat import *
df_reference = concatenate_reference_files(input,output)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-18-188fc684e991> in <module>()
# ----> 1 from src.data_extraction.mri_reference_concat import *
#       2 df_reference = concatenate_reference_files(input,output)
#
# /content/gdrive/My Drive/Lucas_Thimoteo/mmml-alzheimer-diagnosis/src/data_extraction/mri_reference_concat.py in <module>()
#       3 from pathlib import Path
#       4
# ----> 5 from src.utils.utils import *
#       6
#       7 # import os
#
# ModuleNotFoundError: No module named 'src.utils.utils'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ...

# %% [markdown]
# # ensemble_preprocessing.py
