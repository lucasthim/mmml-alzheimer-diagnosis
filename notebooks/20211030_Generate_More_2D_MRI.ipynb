# %% [markdown]
# # Imports

# %%
# !pip install antspyx

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import scipy.stats as sp
from joblib import dump, load
import matplotlib.pyplot as plt

# %matplotlib inline
plt.style.use('seaborn')
pd.set_option('display.max_columns', 150)
pd.set_option('display.max_rows', 150)

# %%
from google.colab import drive
import os
# %load_ext autoreload
# %autoreload 2

drive.mount('/content/gdrive', force_remount=True)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# Mounted at /content/gdrive

# %%
# !git config --global user.password "0fbeca7ef860e10864645575aaddb4146df87f6f"
# !git config --global user.email "lucasthim@yahoo.com"
# !git config --global user.name "Lucas Thimoteo"
# !git config --global credential.helper cache

# %%
# os.chdir('/content/gdrive/MyDrive/Lucas_Thimoteo/')
# !git clone https://lucasthim:0fbeca7ef860e10864645575aaddb4146df87f6f@github.com/lucasthim/mmml-alzheimer-diagnosis.git
# Out:
# Cloning into 'mmml-alzheimer-diagnosis'...
# remote: Enumerating objects: 529, done.
# remote: Counting objects: 100% (341/341), done.
# remote: Compressing objects: 100% (210/210), done.
# remote: Total 529 (delta 216), reused 241 (delta 121), pack-reused 188
# Receiving objects: 100% (529/529), 64.39 MiB | 15.10 MiB/s, done.
# Resolving deltas: 100% (305/305), done.
# Checking out files: 100% (73/73), done.

# %% [markdown]
# # AD vs CN subjects

# %%
os.chdir('/content/gdrive/MyDrive/Lucas_Thimoteo/mmml-alzheimer-diagnosis/src/data_preparation')
from datetime import datetime
from mri_preparation import *

ensemble_reference_path = '/content/gdrive/MyDrive/Lucas_Thimoteo/data/tabular/PROCESSED_ENSEMBLE_REFERENCE.csv'
preprocessed_mri_reference = '/content/gdrive/MyDrive/Lucas_Thimoteo/data/reference/PREPROCESSED_MRI_REFERENCE.csv'
preparation_output_path = '/content/gdrive/MyDrive/Lucas_Thimoteo/data/mri/processed/storage/'

# %% [markdown]
# ## Coronal

# %%
orientations = {
    'coronal':list(range(0,35)) + list(range(66,100)),
    # 'axial':range(15,36),
    # 'sagittal':range(15,36),
    # 'axial':range(65,86),
    # 'sagittal':range(65,86)
}
start = datetime.now()
execute_mri_batch_preparation(mri_reference_path = preprocessed_mri_reference,
                              ensemble_reference_path = ensemble_reference_path,
                              output_path = preparation_output_path,
                              orientations = orientations)
end = datetime.now()
print("-----------------")

print("total processing time: ",end-start)
# Out:
# A saída de streaming foi truncada nas últimas 5000 linhas.
#
# Generating 2D coronal slices for image I65975...
# Saving coronal slices for image I65975...
#
# Generating 2D coronal slices for image I118761...
# Saving coronal slices for image I118761...
#
# Generating 2D coronal slices for image I119802...
# Saving coronal slices for image I119802...
#
# Generating 2D coronal slices for image I122861...
# Saving coronal slices for image I122861...
#
# Generating 2D coronal slices for image I128360...
# Saving coronal slices for image I128360...
#
# Generating 2D coronal slices for image I73053...
# Saving coronal slices for image I73053...
#
# Generating 2D coronal slices for image I120057...
# Saving coronal slices for image I120057...
#
# Generating 2D coronal slices for image I87005...
# Saving coronal slices for image I87005...
#
# Generating 2D coronal slices for image I118766...
# Saving coronal slices for image I118766...
#
# Generating 2D coronal slices for image I118768...
# ...

# %% [markdown]
# ## Axial

# %%
orientations = {
    # 'coronal':range(35,66),
    # 'axial':range(65,86),
    # 'axial':range(15,36),
    'axial':list(range(0,15)) + list(range(36,65))+ list(range(86,100)),
    # 'sagittal':range(15,36),
    # 'sagittal':range(65,86)
}
start = datetime.now()
execute_mri_batch_preparation(mri_reference_path = preprocessed_mri_reference,
                              ensemble_reference_path = ensemble_reference_path,
                              output_path = preparation_output_path,
                              orientations = orientations)
end = datetime.now()
print("-----------------")

print("total processing time: ",end-start)
# Out:
# A saída de streaming foi truncada nas últimas 5000 linhas.
# Generating 2D axial slices for image I222779...
# Saving axial slices for image I222779...
#
# Generating 2D axial slices for image I222777...
# Saving axial slices for image I222777...
#
# Generating 2D axial slices for image I222775...
# Saving axial slices for image I222775...
#
# Generating 2D axial slices for image I65975...
# Saving axial slices for image I65975...
#
# Generating 2D axial slices for image I118761...
# Saving axial slices for image I118761...
#
# Generating 2D axial slices for image I119802...
# Saving axial slices for image I119802...
#
# Generating 2D axial slices for image I122861...
# Saving axial slices for image I122861...
#
# Generating 2D axial slices for image I128360...
# Saving axial slices for image I128360...
#
# Generating 2D axial slices for image I73053...
# Saving axial slices for image I73053...
#
# Generating 2D axial slices for image I120057...
# ...

# %% [markdown]
# ## Sagittal

# %%
orientations = {
    # 'coronal':range(35,66),
    # 'axial':range(15,36),
    'sagittal':list(range(0,15)) + list(range(36,65))+ list(range(86,100)),
    # 'sagittal':range(15,36),
    # 'sagittal':range(65,86)
}
start = datetime.now()
execute_mri_batch_preparation(mri_reference_path = preprocessed_mri_reference,
                              ensemble_reference_path = ensemble_reference_path,
                              output_path = preparation_output_path,
                              orientations = orientations)
end = datetime.now()
print("-----------------")

print("total processing time: ",end-start)
# Out:
# A saída de streaming foi truncada nas últimas 5000 linhas.
# Saving sagittal slices for image I272814...
#
# Generating 2D sagittal slices for image I267767...
# Saving sagittal slices for image I267767...
#
# Generating 2D sagittal slices for image I270069...
# Saving sagittal slices for image I270069...
#
# Generating 2D sagittal slices for image I263738...
# Saving sagittal slices for image I263738...
#
# Generating 2D sagittal slices for image I222781...
# Saving sagittal slices for image I222781...
#
# Generating 2D sagittal slices for image I222779...
# Saving sagittal slices for image I222779...
#
# Generating 2D sagittal slices for image I222777...
# Saving sagittal slices for image I222777...
#
# Generating 2D sagittal slices for image I222775...
# Saving sagittal slices for image I222775...
#
# Generating 2D sagittal slices for image I65975...
# Saving sagittal slices for image I65975...
#
# Generating 2D sagittal slices for image I118761...
# ...

# %% [markdown]
# # Preparing MCI subjects

# %%
ensemble_reference_path = '/content/gdrive/MyDrive/Lucas_Thimoteo/data/tabular/PROCESSED_ENSEMBLE_REFERENCE.csv'
preprocessed_mri_reference = '/content/gdrive/MyDrive/Lucas_Thimoteo/data/reference/PREPROCESSED_MRI_REFERENCE.csv'

# %%
df_ens = pd.read_csv(ensemble_reference_path).query("CONFLICT_DIAGNOSIS == False")
df_mri = pd.read_csv(preprocessed_mri_reference)
df_ens['DATASET'].value_counts()

# %%
print('TRAIN:\n',df_ens.query("DATASET == 'train'")['MACRO_GROUP'].value_counts())
print('\nVALIDATION:\n',df_ens.query("DATASET == 'validation'")['MACRO_GROUP'].value_counts())
print('\nTEST:\n',df_ens.query("DATASET == 'test'")['MACRO_GROUP'].value_counts())
# Out:
# TRAIN:
#  0    551
# 1    149
# Name: MACRO_GROUP, dtype: int64
#
# VALIDATION:
#  0    279
# 1     78
# Name: MACRO_GROUP, dtype: int64
#
# TEST:
#  0    283
# 1     66
# Name: MACRO_GROUP, dtype: int64

# %%
print('TRAIN:\n',df_ens.query("DATASET == 'train'")['SUBJECT'].unique().shape)
print('\nVALIDATION:\n',df_ens.query("DATASET == 'validation'")['SUBJECT'].unique().shape)
print('\nTEST:\n',df_ens.query("DATASET == 'test'")['SUBJECT'].unique().shape)
# Out:
# TRAIN:
#  (258,)
#
# VALIDATION:
#  (130,)
#
# TEST:
#  (129,)

# %%
os.chdir('/content/gdrive/MyDrive/Lucas_Thimoteo/mmml-alzheimer-diagnosis/src/data_preparation')
from ensemble_preparation import *

# %%
os.chdir('/content/gdrive/MyDrive/Lucas_Thimoteo/mmml-alzheimer-diagnosis/src/data_preprocessing')
from ensemble_preprocessing import *

# %%
def execute_ensemble_preprocessing(preprocessed_cognitive_data_path,
                            preprocessed_mri_raw_data_path,
                            ensemble_data_output_path,
                            classes=[1,0]):
    ''' 

    Execute preprocessing for the reference data that will be used in the ensemble model.

    Main steps are:
    1. Remove duplicates from MRI reference (sometimes the same image is downloaded twice)
    2. Merge files from MRI reference and Cognitive Tests reference.
    3. Remove conflicting diagnosis between MRI and Congnitive Tests.
    4. Save preprocessed ensemble reference file.

    '''

    print("Merging files from MRI reference and Cognitive Tests reference...")
    df_cog = pd.read_csv(preprocessed_cognitive_data_path).dropna().query("IMAGEUID != 999999")
    df_mri = pd.read_csv(preprocessed_mri_raw_data_path)
    df_mri.rename(columns={'IMAGE_DATA_ID':'IMAGEUID'},inplace=True)
    df_mri['IMAGEUID'] = df_mri['IMAGEUID'].str.replace('I','').astype(np.int64)

    if check_duplicates(df_mri):
        df_mri = remove_duplicates(df_mri)
        print("Duplicates found and removed!")

    print("Normalizing classes from both files...")
    df_ensemble = pd.merge(df_cog,df_mri[['SUBJECT','IMAGEUID','GROUP','MACRO_GROUP','VISIT','ACQ_DATE']],on=['SUBJECT','IMAGEUID'])
    if 'CN' in df_ensemble['MACRO_GROUP'].unique() or 'AD' in df_ensemble['MACRO_GROUP'].unique() or 'MCI' in df_ensemble['MACRO_GROUP'].unique() :
        df_ensemble['MACRO_GROUP'].replace({'AD':1,'CN':0,'MCI':2},inplace=True)
    print("Initial data merged!")
    
    df_ensemble = mark_conflicting_diagnosis(df_ensemble)
    df_ensemble = df_ensemble.query("MACRO_GROUP in @classes")

    print("Saving ensemble reference file...")
    df_ensemble.to_csv(ensemble_data_output_path,index=False)
    return df_ensemble,df_cog,df_mri

# %%
preprocessed_cognitive_data_path = '/content/gdrive/MyDrive/Lucas_Thimoteo/data/tabular/COGNITIVE_DATA_PREPROCESSED.csv'
preprocessed_mri_raw_data_path = '/content/gdrive/MyDrive/Lucas_Thimoteo/data/reference/PREPROCESSED_MRI_REFERENCE.csv'
ensemble_data_output_path = '/content/gdrive/MyDrive/Lucas_Thimoteo/data/tabular/PREPROCESSED_ENSEMBLE_REFERENCE_ALL.csv'
classes = [0,1,2]

df_ens_preproc,df_cog,df_mri = execute_ensemble_preprocessing(preprocessed_cognitive_data_path,
                            preprocessed_mri_raw_data_path,
                            ensemble_data_output_path,
                            classes)
# Out:
# Merging files from MRI reference and Cognitive Tests reference...
# Found 0 duplicates!
# Normalizing classes from both files...
# Initial data merged!
# Found 336 cases with diverging diagnosis between MRI and Cognitive Tests.
# Saving ensemble reference file...

# %%
df_ens_preproc['MACRO_GROUP'].value_counts()
# Out:
# 0    1137
# 2     636
# 1     293
# Name: MACRO_GROUP, dtype: int64

# %%
def execute_ensemble_preparation(ensemble_data_path,classes=[0,1,2],test_size=0.25,validation_size=0.25):
    
    '''
    Prepare ensemble data for training process by splitting the data between train, validation and test set.

    The validation and test sets should remain the same for all experiments: MRI, cognitive tests and ensemble.

    Training data can vary from experiment to experiment. 
    For example, MRI CNNs training can contain more images than the images aligned with the ensemble data. 
    The same holds true for cognitive tests data.
    
    Parameters:
    ------------
    ensemble_data_path: path where the preprocessed ensemble data reference is located.

    test_size: size of the test set. Has to be bigger than 0 and less than 1.

    validation_size: size of the validation set. Has to be bigger than 0 and less than 1.

    Results
    ------------

    Saves a prepared ensemble reference file with a DATASET flag (train, test,validation or nan)
    '''

    df_ensemble = pd.read_csv(ensemble_data_path)
    print("Spliting ensemble data in train, validation and test...")
    df_ensemble.sort_values('SUBJECT',inplace=True)
    df_no_conflict = df_ensemble.query("CONFLICT_DIAGNOSIS == False")
    df_train,df_validation = train_test_split_by_subject(df_no_conflict,test_size = validation_size,labels = classes,label_column='DIAGNOSIS',random_seed=42)
    corrected_test_size = test_size * (df_no_conflict.shape[0]/df_train.shape[0])
    df_train,df_test = train_test_split_by_subject(df_train,test_size = corrected_test_size,labels = classes,label_column='DIAGNOSIS',random_seed=42)
    print("Ensemble train size:",df_train.shape)
    print("Ensemble validation size:",df_validation.shape)
    print("Ensemble test size:",df_test.shape)
    
    df_ensemble['DATASET'] = np.nan
    df_train['DATASET'] = 'train'
    df_validation['DATASET'] = 'validation'
    df_test['DATASET'] = 'test'

    df_ensemble_processed = pd.concat([df_train,df_validation,df_test,df_ensemble.query("CONFLICT_DIAGNOSIS == True")])
    final_path = ensemble_data_path.replace('PREPROCESSED','PROCESSED')
    df_ensemble_processed.to_csv(final_path,index=False)
    print("Processed ensemble reference file saved at: ",final_path)
    return df_train,df_validation,df_test

# %%
df_train,df_validation,df_test = execute_ensemble_preparation(ensemble_data_output_path,test_size=0.25,validation_size=0.25)
df_ens_proc = pd.read_csv('/content/gdrive/MyDrive/Lucas_Thimoteo/data/tabular/PROCESSED_ENSEMBLE_REFERENCE_ALL.csv')
# Out:
# Spliting ensemble data in train, validation and test...
# Ensemble train size: (854, 39)
# Ensemble validation size: (438, 39)
# Ensemble test size: (438, 39)
# Processed ensemble reference file saved at:  /content/gdrive/MyDrive/Lucas_Thimoteo/data/tabular/PROCESSED_ENSEMBLE_REFERENCE_ALL.csv

# %% [markdown]
# # Merging Final MRI Reference File

# %%
df_previous = pd.read_csv('/content/gdrive/MyDrive/Lucas_Thimoteo/data/reference/PROCESSED_MRI_REFERENCE_ALL_ORIENTATIONS_20211012_2041.csv')
df_cor = pd.read_csv('/content/gdrive/MyDrive/Lucas_Thimoteo/data/reference/PROCESSED_MRI_REFERENCE_20211030_0604.csv')
df_axi = pd.read_csv('/content/gdrive/MyDrive/Lucas_Thimoteo/data/reference/PROCESSED_MRI_REFERENCE_20211030_0646.csv')
df_sag = pd.read_csv('/content/gdrive/MyDrive/Lucas_Thimoteo/data/reference/PROCESSED_MRI_REFERENCE_20211030_0728.csv')
df_ref = pd.concat([df_previous,df_cor,df_axi,df_sag])
now = datetime.now().strftime("%Y%m%d_%H%M")
df_ref.to_csv(f'/content/gdrive/MyDrive/Lucas_Thimoteo/data/reference/PROCESSED_MRI_REFERENCE_ALL_ORIENTATIONS_{now}.csv',index=False)
f'/content/gdrive/MyDrive/Lucas_Thimoteo/data/reference/PROCESSED_MRI_REFERENCE_ALL_ORIENTATIONS_{now}.csv'
# Out:
# '/content/gdrive/MyDrive/Lucas_Thimoteo/data/reference/PROCESSED_MRI_REFERENCE_ALL_ORIENTATIONS_20211030_2026.csv'

# %%
df_ref['SLICE'].unique().shape
# Out:
# (100,)
