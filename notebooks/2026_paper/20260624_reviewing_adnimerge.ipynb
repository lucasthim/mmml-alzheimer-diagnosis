# %%
import pandas as pd

# %%
df = pd.read_csv('./../../data/tabular/ADNIMERGE.csv')

# %%
df.head()
# Out:
#     RID        PTID VISCODE   SITE COLPROT ORIGPROT    EXAMDATE  IMAGEUID  \
# 0     2  011_S_0002      bl  107.0   ADNI1    ADNI1  2005-09-29   35475.0
# 1  6210  014_S_6210      sc   11.0   ADNI3    ADNI3  2014-02-14  969431.0
# 2  6237  153_S_6237      sc   57.0   ADNI3    ADNI3  2018-02-15  970943.0
# 3  1286  100_S_1286    init   41.0   ADNI3    ADNI1  2018-02-07  959489.0
# 4  6165  100_S_6165      sc   41.0   ADNI3    ADNI3  2018-02-16       NaN
#
#     DX DX_bl  ...  EcogPtOrgan EcogPtDivatt  EcogPtTotal EcogSPMem EcogSPLang  \
# 0   CN    CN  ...          NaN          NaN          NaN       NaN        NaN
# 1   CN    CN  ...          NaN          NaN          NaN       NaN        NaN
# 2   CN    CN  ...          NaN          NaN          NaN       NaN        NaN
# 3   CN    CN  ...          NaN          NaN          NaN       NaN        NaN
# 4  MCI   MCI  ...          NaN          NaN          NaN       NaN        NaN
#
# ...

# %%
df.columns
# Out:
# Index(['RID', 'PTID', 'VISCODE', 'SITE', 'COLPROT', 'ORIGPROT', 'EXAMDATE',
#        'IMAGEUID', 'DX', 'DX_bl', 'AGE', 'PTGENDER', 'PTEDUCAT', 'PTETHCAT',
#        'PTRACCAT', 'PTMARRY', 'CDRSB', 'ADAS11', 'ADAS13', 'ADASQ4', 'MMSE',
#        'RAVLT_immediate', 'RAVLT_learning', 'RAVLT_forgetting',
#        'RAVLT_perc_forgetting', 'LDELTOTAL', 'DIGITSCOR', 'TRABSCOR', 'FAQ',
#        'MOCA', 'EcogPtMem', 'EcogPtLang', 'EcogPtVisspat', 'EcogPtPlan',
#        'EcogPtOrgan', 'EcogPtDivatt', 'EcogPtTotal', 'EcogSPMem', 'EcogSPLang',
#        'EcogSPVisspat', 'EcogSPPlan', 'EcogSPOrgan', 'EcogSPDivatt',
#        'EcogSPTotal'],
#       dtype='object')
