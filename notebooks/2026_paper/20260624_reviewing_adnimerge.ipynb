# %%
import pandas as pd

# %%
df_adnimerge = pd.read_csv('./../../data/tabular/ADNIMERGE.csv')
df_adnimerge.shape
# Out:
# (15836, 44)

# %%
df_selected_mris = pd.read_csv('./../../data/reference/REFERENCE_TABLE_FOR_MRI.csv')
df_selected_mris.shape
# Out:
# (10002, 10)

# %%
df_selected_mris
# Out:
#            SUBJECT_IMAGE_ID IMAGE_DATA_ID     SUBJECT GROUP MACRO_GROUP SEX  \
# 0        002_S_0295#I118671       I118671  002_S_0295    CN          CN   M
# 1        002_S_0295#I118692       I118692  002_S_0295    CN          CN   M
# 2         002_S_0295#I64025        I64025  002_S_0295    CN          CN   M
# 3        002_S_0295#I123685       I123685  002_S_0295    CN          CN   M
# 4        002_S_0295#I150177       I150177  002_S_0295    CN          CN   M
# ...                     ...           ...         ...   ...         ...  ..
# 9997    941_S_7074#I1588331      I1588331  941_S_7074    CN          CN   M
# 9998   941_S_7074#I10283169     I10283169  941_S_7074    CN          CN   M
# 9999    941_S_7085#I1600180      I1600180  941_S_7085   MCI         MCI   F
# 10000   941_S_7087#I1591321      I1591321  941_S_7087    CN          CN   M
# 10001   941_S_7106#I1619403      I1619403  941_S_7106   MCI         MCI   F
#
# ...

# %%
df_selected_mris.SUBJECT.unique().shape
# Out:
# (3011,)

# %%
sample_subjects = ["002_S_0295", "002_S_0413", "002_S_0559", "002_S_0619", "002_S_0685", "002_S_0729", "002_S_0782", "002_S_0816", "002_S_0938", "002_S_0954", "002_S_0955", "002_S_1018", "002_S_1070", "002_S_1155", "002_S_1261", "002_S_1268", "002_S_1280", "002_S_2010", "002_S_2043", "002_S_2073", "002_S_4213", "002_S_4225", "002_S_4229", "002_S_4237", "002_S_4262", "002_S_4270", "002_S_4447", "002_S_4473", "002_S_4521", "002_S_4654", "002_S_4746", "002_S_4799", "002_S_5018", "002_S_5178", "002_S_5230", "002_S_5256", "002_S_6007", "002_S_6009", "002_S_6030", "002_S_6053", "002_S_6066", "002_S_6103", "002_S_6404", "002_S_6456", "002_S_6652", "002_S_6680", "002_S_6695", "003_S_0907", "003_S_0908", "003_S_0981"]

# %%
df_downloaded_mris = pd.read_csv('./../../data/reference/DOWNLOAD_RAW_MRI.csv')
