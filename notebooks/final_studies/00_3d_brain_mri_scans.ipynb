# %%
import os

import ants
import scipy.misc
import numpy as np
from itkwidgets import view
import matplotlib.pyplot as plt

# %matplotlib inline
# plt.style.use('seaborn')

# %%
def show_slices(slices,img):
    """ Function to display row of image slices """
    fig, axes = plt.subplots(1, len(slices))
    fig.set_size_inches(11,8)
    for i, slice in enumerate(slices):

        axes[i].imshow(slice.T, cmap="gray", origin="lower")
    plt.suptitle(f"Center slices for MRI image \n Image size: {img.shape}",fontsize=20)
    # print("image size:",img.shape)
    plt.tight_layout()
    plt.subplots_adjust(bottom=0.20)
    plt.show()

def show_brain_center_slice(img: np.memmap):
    slice_0 = img[int(img.shape[0]/2), :, :]
    slice_1 = img[:, int(img.shape[1]/2), :]
    slice_2 = img[:, :, int(img.shape[2]/2)]
    show_slices([slice_0, slice_1, slice_2],img)

# img_stripped = img.copy()
# img_stripped[~mask] = 0

# %%
os.chdir('/home/lucas/projects/mmml-alzheimer-diagnosis/src/utils/')
from base_mri import load_mri

# %%
img = load_mri("/home/lucas/projects/mmml-alzheimer-diagnosis/data/mri/002_S_0295_MR_MT1__N3m_Br_20110623105302806_S110476_I241350_CN.nii.gz")
img
# Out:
# ANTsImage (LPI)
# 	 Pixel Type : float (float32)
# 	 Components : 1
# 	 Dimensions : (100, 100, 100)
# 	 Spacing    : (1.0, 1.0, 1.0)
# 	 Origin     : (-47.0, -65.0, 47.0)
# 	 Direction  : [-1.  0.  0.  0. -1.  0.  0.  0.  1.]

# %%
img_np = img.numpy()#.astype(np.uint16)
show_brain_center_slice(img_np)

# %%
ants.plot(img,slices=[0,1,2,3,50,96,97,98,99],axis=0,ncol=9,title='Sagittal slices - left to right')
ants.plot(img,slices=[0,1,2,3,50,96,97,98,99],axis=1,ncol=9,title='Coronal slices - posterior (back) to anterior (front)')
ants.plot(img,slices=[0,1,2,3,50,96,97,98,99],axis=2,ncol=9,title='Axial slices - inferior to superior')

# %%
tiles = ants.create_tiled_mosaic(img,direction=0);
tiles
# Out:
# Slices[0]: 100
# Rows:  10
# Columns:  10
# Processing slice 0
# Processing slice 1
# Processing slice 2
# Processing slice 3
# Processing slice 4
# Processing slice 5
# Processing slice 6
# Processing slice 7
# Processing slice 8
# Processing slice 9
# Processing slice 10
# Processing slice 11
# Processing slice 12
# Processing slice 13
# Processing slice 14
# Processing slice 15
# Processing slice 16
# Processing slice 17
# Processing slice 18
# Processing slice 19
# Processing slice 20
# Processing slice 21
# Processing slice 22
# Processing slice 23
# Processing slice 24
# Processing slice 25
# Processing slice 26
# Processing slice 27
# Processing slice 28
# Processing slice 29
# Processing slice 30
# Processing slice 31
# Processing slice 32
# Processing slice 33
# Processing slice 34
# Processing slice 35
# Processing slice 36
# Processing slice 37
# Processing slice 38
# Processing slice 39
# Processing slice 40
# Processing slice 41
# Processing slice 42
# ...

# %%
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1000x1000 at 0x7F9DEBDD67F0>
